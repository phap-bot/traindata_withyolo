# %% [markdown]
# <a href="https://colab.research.google.com/github/phap-bot/traindata_withyolo/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !wget -P /content https://huggingface.co/jameslahm/yolov10n.pt
# Out:
# --2026-03-03 17:43:46--  https://huggingface.co/jameslahm/yolov10n.pt
# Resolving huggingface.co (huggingface.co)... 13.35.202.121, 13.35.202.97, 13.35.202.34, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.121|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.

# %%
from ultralytics import YOLOv10

model = YOLOv10.from_pretrained('jameslahm/yolov10n')
source = 'http://images.cocodataset.org/val2017/000000039769.jpg'
model.predict(source=source, save=True)
# Out:
# ...
# 100%|██████████| 169k/169k [00:00<00:00, 266kB/s]
# image 1/1 /content/data/000000039769.jpg: 480x640 2 cats, 1 couch, 2 remotes, 23.4ms
# Speed: 2.8ms preprocess, 23.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# %cd /content/data

#unzip
# !unzip firedata.zip

# cau truc lai thu muc

# %cd /content/data
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# !mv *.jpg train/images
# !mv *.txt train/labels
# Out:
# /content/data
# Archive:  firedata.zip
#   inflating: 000001.jpg
# replace __MACOSX/._000001.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000001.txt
# replace __MACOSX/._000001.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000002.jpg
# replace __MACOSX/._000002.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000002.txt
# replace __MACOSX/._000002.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000003.jpg
# replace __MACOSX/._000003.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000004.jpg
# replace __MACOSX/._000004.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
#   inflating: 000004.txt
# replace __MACOSX/._000004.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/._000004.txt
#   inflating: 000005.jpg
# replace __MACOSX/._000005.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: __MACOSX/._000005.jpg
#   inflating: 000005.txt
# ...

# %%
from torch import DoubleStorage
# tao file mydataset.yaml
# %cd /content/data/
# !rm mydataset.yaml
# !echo 'names'>> mydataset.yaml
# !echo 'Fire'>> mydataset.yaml
# !echo 'nc: 1'>> mydataset.yaml
# !echo 'train:/content/data/train '>> mydataset.yaml
# !echo 'test:/content/data/train '>> mydataset.yaml
# !echo 'val:/content/data/train '>> mydataset.yaml
# Out:
# /content/data

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 135.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 129.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %%
# train yolov8

# !yolo task=detect mode=train epochs=20 batch=32 plots=True model='/content/yolov10n.pt' data='/content/data/mydataset.yaml'
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 956, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 76, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 144, in __init__
#     self._load(model, task=task)
# ...

# %%
from ultralytics import YOLOv10

model = YOLOv10.from_pretrained('jameslahm/yolov10n')
source = 'http://images.cocodataset.org/val2017/000000039769.jpg'
model.predict(source=source, save=True)
